# %% [markdown]
# <a href="https://colab.research.google.com/github/HOWARD258ym/HOWARD258ym/blob/main/taining_NN_conclusion_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # taining NN

# %% [markdown]
# ![image.png](data:image/png;base64,...)
